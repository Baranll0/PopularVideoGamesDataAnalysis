# %%
import pandas as pd
import numpy as np
import ast

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("backloggd_games.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  60000 non-null  object
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  object
#  9   Playing       60000 non-null  object
#  10  Backlogs      60000 non-null  object
#  11  Wishlist      60000 non-null  object
#  12  Lists         60000 non-null  object
#  13  Reviews       60000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 6.4+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0        Rating
# count  60000.000000  25405.000000
# mean   29999.500000      3.033171
# std    17320.652413      0.735573
# min        0.000000      0.300000
# 25%    14999.750000      2.600000
# 50%    29999.500000      3.100000
# 75%    44999.250000      3.500000
# max    59999.000000      5.000000

# %%
df.dropna()
df['Release_Date'].head()
# Out:
# 0    Feb 25, 2022
# 1    Mar 03, 2017
# 2    Dec 07, 2018
# 3    Feb 24, 2017
# 4    Sep 15, 2015
# Name: Release_Date, dtype: object

# %%
df['Release_Date'] = df['Release_Date'].replace('TBD', np.nan)
df['Release_Date'] = pd.to_datetime(df['Release_Date'], format="%b %d, %Y")
df['Year'] = df['Release_Date'].dt.year
game_per_year=df.groupby('Year').size()
plt.figure(figsize=(10,6))
game_per_year.plot(kind='line')
plt.title("Number of Games Released per Year")
plt.xlabel('Year')
plt.ylabel('Number of Games')
plt.show()

# %%
def plays_to_numeric(play_str):
    if isinstance(play_str, str):  # Gelen değer string mi diye kontrol
        if 'K' in play_str:
            return float(play_str.replace('K', '')) * 1000
        elif 'M' in play_str:
            return float(play_str.replace('M', '')) * 1000000
        else:
            return float(play_str)
    else:
        return play_str  # Eğer string değilse olduğu gibi döndür

# %%
# 'Plays' sütununu sayısal değere dönüştürme
df['Plays'] = df['Plays'].apply(plays_to_numeric)

# 'Developers' sütununu işleme
df['Developer'] = df['Developers'].str.split(', ').str.get(0)
df['Developer'] = df['Developer'].str.replace('[', '', regex=False)
df['Developer'] = df['Developer'].str.replace(']', '', regex=False)
df = df[df['Developer'] != '']

# Her geliştirici için oyunların toplam oyun sayısını hesaplama
popularity = df.groupby('Developer')['Plays'].sum()

# En popüler geliştiricileri sıralama (yüksekten düşüğe)
popularity = popularity.sort_values(ascending=False)

top_10_popular = popularity.head(20)

plt.figure(figsize=(15, 10))
sns.barplot(x=top_10_popular.index, y=top_10_popular.values, color='#00A0FF')
plt.title('Top 10 Popular Developers by Total Plays')
plt.xlabel('Developer')
plt.ylabel('Total Plays')
plt.xticks(rotation=50)
plt.show()

# %%
df['Genres']=df['Genres'].apply(ast.literal_eval)
df=df[df['Genres'].apply(lambda x:x!=[])]
genres = df.explode('Genres')
genre_counts = genres['Genres'].value_counts()
top_20_genres=genre_counts[:20]

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=top_20_genres.index,y=top_20_genres.values,color='#00A0FF')
plt.title('Game Genre Popularity')
plt.xlabel('Genre')
plt.ylabel('Total Games')
plt.xticks(rotation=90)
plt.show()

# %%
df['Platforms'] = df['Platforms'].apply(lambda x: eval(x))
df_exploded = df.explode('Platforms')
df_exploded['Rating'] = df_exploded['Rating'].fillna(df_exploded['Rating'].mean())
df_exploded = df_exploded.dropna()
platform_ratings = df_exploded.groupby('Platforms')['Rating'].mean()
platform_ratings
# Out:
# Platforms
# 1292 Advanced Programmable Video System    2.959760
# 3DO Interactive Multiplayer                2.885138
# AY-3-8500                                  3.071712
# AY-3-8605                                  3.071712
# AY-3-8606                                  3.100000
#                                              ...
# Xbox One                                   3.080209
# Xbox Series                                3.151049
# ZX Spectrum                                2.956201
# Zeebo                                      3.107698
# iOS                                        3.029231
# Name: Rating, Length: 175, dtype: float64

# %%
top_platforms = platform_ratings.sort_values(ascending=False).head(50)
plt.figure(figsize=(10, 8))
sns.barplot(x=top_platforms.values, y=top_platforms.index, palette='viridis')
plt.title('Average Game Ratings by Platform')
plt.xlabel('Average Rating')
plt.ylabel('Platform')
plt.show()

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())
correlation=df['Plays'].corr(df['Rating'])
# Out:
# 0.1950455640307788

# %%
plt.figure(figsize=(10,8))
plt.scatter(df['Plays'],df['Rating'],alpha=0.5)
plt.title('Correlation betweetn Number of Plays and Ratings')
plt.xlabel('Number of Plays')
plt.ylabel('Rating')
plt.show()

# %%
df['Developers']=df['Developers'].apply(lambda x: eval(x) if isinstance(x,str) else x)
df_explode=df.explode('Developers')
developer_ratings= df_exploded.groupby('Developers')['Rating'].mean()
top_developer=developer_ratings.idxmax()

df['Developers']=df['Developers'].apply(lambda x: top_developer if top_developer in x else x[0])
# Out:
# 0            FromSoftware
# 1                Nintendo
# 2        Supergiant Games
# 3             Team Cherry
# 4                 tobyfox
#                ...
# 59986       Rrndrln Games
# 59995              FHNBHJ
# 59996        Owlcat Games
# 59998              FHNBHJ
# 59999        Owlcat Games
# Name: Developers, Length: 39760, dtype: object

# %%
top_developers=developer_ratings.sort_values(ascending=True).head(50)
plt.figure(figsize=(15,15))
sns.barplot(y=top_developers.index,x=top_developers.values,palette='viridis')
plt.title('Top 50 Developers by Average Game Rating')
plt.xlabel('Average Rating')
plt.ylabel('Developer')
plt.show()

# %%
def convert_k_to_thousands(s):
    s=s.replace('K','')
    if s:
        return float(s)*1000
    else:
        return 0.0
df['Wishlist']=df['Wishlist'].apply(convert_k_to_thousands)
average_wishlist_additions=df.groupby('Rating')['Wishlist'].mean()
# Out:
# Rating
# 0.300000      1000.000000
# 0.500000      1900.000000
# 0.600000      2857.142857
# 0.700000      4368.421053
# 0.800000      3230.769231
# 0.900000      5954.545455
# 1.000000      2285.714286
# 1.100000     11409.090909
# 1.200000      5485.981308
# 1.300000      3882.978723
# 1.400000      8333.333333
# 1.500000      4400.000000
# 1.600000     11984.375000
# 1.700000      8847.457627
# 1.800000      7415.954416
# 1.900000     11340.000000
# 2.000000      6677.685950
# 2.100000      9622.222222
# 2.200000      9823.308271
# 2.300000     13693.050193
# 2.400000     13785.294118
# 2.500000     17964.379947
# 2.600000     18412.887828
# 2.700000     22109.114249
# 2.800000     23173.734729
# 2.900000     31354.941552
# 3.000000     30866.972477
# 3.060333      3862.644948
# 3.100000     33966.238218
# 3.200000     36302.583799
# 3.300000     53937.470908
# 3.400000     59849.958983
# 3.500000     68781.322314
# 3.600000     81434.249084
# 3.700000     97070.526316
# 3.800000     97757.976190
# 3.900000    114874.328859
# 4.000000    126671.571906
# 4.100000    132081.710214
# 4.200000    121238.987342
# 4.300000    104981.102362
# 4.400000     81445.859873
# 4.500000    115610.714286
# 4.600000     78722.222222
# 4.700000     62852.941176
# 4.800000     39756.756757
# 4.900000     19500.000000
# 5.000000     47900.000000
# Name: Wishlist, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.scatter(average_wishlist_additions.index,average_wishlist_additions.values,color='blue')
plt.title('Average Wishlist Additions per Rating')
plt.xlabel('Rating')
plt.ylabel('Average WiShlist Additions')
plt.show()

# %%
df=df.dropna(subset=['Genres','Rating'])

df['Rating'].dtypes
# Out:
# dtype('float64')
